# %% [markdown]
# # Data Set
#
# - Primero veamos los parámetros las imágenes que queremos procesar.
#
# Para esto solo hay que escribir el número de serie de la imagen que queremos analizar y se mostrarán todos los parámetros de la secuencia NOGSE y los parámetros de la imágen.

# %%
import sys
serial = 416 
file_name = "mousebrain_20200409"
slic = 1 

# %run scripts/data_set.py $serial $file_name $slic
# Out:
# Serial:  416
# Dimensión del array: (192, 192, 2, 2)
# Diccionario con los parámetros de la secuencia NOGSE:
#  params = {'t_nogse': 21.5, 'ramp_grad_str': 500.0, 'ramp_grad_N': 2.0, 'ramp_grad_x': 0.5, 'EchoTime': 55.0}
# Diccionario con los parámetros de las imágenes:
#  params_img = {'Nsegments': 4.0, 'NAverages': 128.0, 'NRepetitions': 1.0, 'DummyScans': 8.0, 'DummyScansDur': 16000.0, 'ScanTime': '34 min 8 s', 'DwUsedSliceThick': 1.0, 'Img size': [192.0, 192.0], 'EffSWh': 500000.0}
# El kernel se bloqueó al ejecutar código en la celda actual o en una celda anterior.
#
# Revise el código de las celdas para identificar una posible causa del error.
#
# Haga clic <a href='https://aka.ms/vscodeJupyterKernelCrash'>aquí</a> para obtener más información.
#
# Vea Jupyter <a href='command:jupyter.viewOutput'>log</a> para obtener más detalles.

# %%
import cv2
import matplotlib.pyplot as plt

serial = 416 # Define el valor de serial
nrois = 1 # Define el valor de nrois
slic =  1 # Define el valor de slice
# Ejecuta el script pasando los valores de serial y nrois como argumentos
get_ipython().system('python scripts/roi_select.py {serial} {nrois} {slic}')

# Mostrar la imagen final
plt.figure(figsize=(4,4))
imagen_final = cv2.imread(f"rois/im={serial}_rois_final_color.jpg")
plt.imshow(imagen_final)
plt.axis('off')  # Desactivar los ejes
plt.show()  # Mostrar la imagen
# Out:
# Average intensity of ROI 1: 14.785203517218186
# <div id='95fab19c-97cc-410e-8ca2-f1e4bbf65a56'></div>

# %%
folder_ranges = '416-448'

get_ipython().system('python scripts/nogse_vs_x_data.py {folder_ranges}')
# Out:
# No se encontraron errores en el procesamiento de las carpetas.
# Figure(800x600)
